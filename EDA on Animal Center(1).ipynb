# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('Austin_Animal_Center_Intakes.csv',encoding='latin-1')

# %%
df.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# ...

# %%
df.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of        Animal ID     Name                DateTime               MonthYear  \
# 0        A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1        A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2        A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3        A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4        A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# ...          ...      ...                     ...                     ...
# 124115   A828158     Odin  01/08/2021 07:01:00 PM  01/08/2021 07:01:00 PM
# 124116   A830183      NaN  03/03/2021 05:12:00 PM  03/03/2021 05:12:00 PM
# 124117   A830180     Gigi  03/03/2021 04:31:00 PM  03/03/2021 04:31:00 PM
# 124118   A830171      NaN  03/03/2021 05:13:00 PM  03/03/2021 05:13:00 PM
# 124119   A830181     Nona  03/03/2021 04:31:00 PM  03/03/2021 04:31:00 PM
#
# ...

# %%
df.describe()
# Out:
#        Animal ID   Name                DateTime               MonthYear  \
# count     124120  85069                  124120                  124120
# unique    110926  19748                   87660                   87660
# top      A721033    Max  09/23/2016 12:00:00 PM  09/23/2016 12:00:00 PM
# freq          33    564                      64                      64
#
#        Found Location Intake Type Intake Condition Animal Type  \
# count          124120      124120           124120      124120
# unique          53703           6               10           5
# top       Austin (TX)       Stray           Normal         Dog
# freq            22859       86455           107952       70447
#
#        Sex upon Intake Age upon Intake                   Breed        Color
# count           124119          124120                  124120       124120
# unique               5              52                    2629          595
# ...

# %% [markdown]
# # NOTE
# ##All the given function used here are the basics of exploratory data analysis and are used for many purposes.
# ##Here as a data analyst you have to first start looking for the missing values.
# ## 1.find the missing values
# ## 2.Explore about the numerical values
# ## 3. Explore categories . :)

# %%
df.isnull().sum()#this is the way you can check abnormalities
# Out:
# Animal ID               0
# Name                39051
# DateTime                0
# MonthYear               0
# Found Location          0
# Intake Type             0
# Intake Condition        0
# Animal Type             0
# Sex upon Intake         1
# Age upon Intake         0
# Breed                   0
# Color                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Name', 'Sex upon Intake']

# %%
plt.plot('df.isnull()')#HOW TO DEAL WITH MISSING VALUE COMES UNDER FEATURE ENGINEERING.

# %%
df.shape
# Out:
# (124120, 12)

# %%
dfo=pd.read_csv('Austin_Animal_Center_Outcomes.csv',encoding='latin-1')

# %%
dfo.head()
# Out:
#   Animal ID   Name                DateTime               MonthYear  \
# 0   A794011  Chunk  05/08/2019 06:20:00 PM  05/08/2019 06:20:00 PM
# 1   A776359  Gizmo  07/18/2018 04:02:00 PM  07/18/2018 04:02:00 PM
# 2   A821648    NaN  08/16/2020 11:38:00 AM  08/16/2020 11:38:00 AM
# 3   A720371  Moose  02/13/2016 05:59:00 PM  02/13/2016 05:59:00 PM
# 4   A674754    NaN  03/18/2014 11:47:00 AM  03/18/2014 11:47:00 AM
#
#   Date of Birth Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 0    05/02/2017    Rto-Adopt             NaN         Cat    Neutered Male
# 1    07/12/2017     Adoption             NaN         Dog    Neutered Male
# 2    08/16/2019   Euthanasia             NaN       Other          Unknown
# 3    10/08/2015     Adoption             NaN         Dog    Neutered Male
# 4    03/12/2014     Transfer         Partner         Cat      Intact Male
#
#   Age upon Outcome                               Breed              Color
# ...

# %%
dfo.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %%
color_final=dfo.Color.value_counts()

# %%
final_df=pd.merge(df,dfo)

# %%
final_df.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color', 'Date of Birth', 'Outcome Type',
#        'Outcome Subtype', 'Sex upon Outcome', 'Age upon Outcome'],
#       dtype='object')

# %%
final_df.DateTime.value_counts()#here i am counting the value of different time and it occurence.
# Out:
# 06/18/2016 11:23:00 AM    1
# 04/25/2017 03:57:00 PM    1
# 06/21/2016 06:13:00 PM    1
# 05/18/2017 03:04:00 PM    1
# 04/09/2019 03:58:00 PM    1
# Name: DateTime, dtype: int64

# %%
final_df.Breed.value_counts()
# Out:
# Domestic Shorthair Mix            3
# Plott Hound/Labrador Retriever    1
# Chihuahua Shorthair Mix           1
# Name: Breed, dtype: int64

# %%
 Breed=final_df.Breed.value_counts().index#only index

# %%
final_df.Breed.value_counts().values#only values
# Out:
# array([3, 1, 1], dtype=int64)

# %%
#pie charts

# %%
#plt.pie(color_final,labels=color_final)#only running this statement will give a very bizzare pie chart
# Out:
# ([<matplotlib.patches.Wedge at 0x1da99646820>,
# ...
#  [Text(1.0407078754485086, 0.3562683230087284, '13070'),
#   Text(0.664292851070102, 0.8767639408741418, '10412'),
#   Text(0.22639710325442233, 1.0764498834771672, '7067'),
#   Text(-0.11839847449061687, 1.0936095286885055, '5421'),
#   Text(-0.3828182694906543, 1.0312372047905278, '4391'),
#   Text(-0.5936249625032143, 0.9260720295382306, '4112'),
#   Text(-0.7654483392668135, 0.7899929366226495, '3797'),
#   Text(-0.8998967512562732, 0.6326024320838525, '3671'),
#   Text(-0.9985213669421441, 0.46147056218137283, '3454'),
#   Text(-1.0631711742792294, 0.2822535282006666, '3418'),
#   Text(-1.095753665321805, 0.09656036937496573, '3382'),
#   Text(-1.09678165505708, -0.08408329875934338, '3133'),
#   Text(-1.0716320731638815, -0.2482029406886255, '2854'),
#   Text(-1.0256291891940332, -0.39759875034158537, '2782'),
#   Text(-0.9613659938492859, -0.5345796721445503, '2673'),
#   Text(-0.8849521894780725, -0.6533449489649138, '2418'),
# ...

# %%
#top 3 colours#you can change it on your convinence
plt.pie(color_final[:3],labels=color_final[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1da9af64310>,
# ...
#  [Text(0.24724589289871685, 1.071853286809681, '13070'),
#   Text(-0.8969660991054587, -0.6367509851233343, '10412'),
#   Text(0.8220680527218807, -0.7308926847999337, '7067')])

# %%
##Numeracal variables.
final_df.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color', 'Date of Birth', 'Outcome Type',
#        'Outcome Subtype', 'Sex upon Outcome', 'Age upon Outcome'],
#       dtype='object')

# %%
Month_Year=final_df.MonthYear.value_counts()

# %%
plt.bar(Month_Year,height=2000)
# Out:
# <BarContainer object of 5 artists>
